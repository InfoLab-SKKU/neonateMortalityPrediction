# %% [markdown]
# # Handling Unbalanced Neonates Data
# * by Firuz Juraev (PhD student)

# %%
import pandas as pd 
from datetime import datetime
import seaborn as sns
import glob
from os import listdir 
import os.path
from os import path
import numpy as np 
import warnings
warnings.filterwarnings('ignore')

# %%
def side_by_side(*objs, **kwds):
    from pandas.io.formats.printing import adjoin
    space = kwds.get('space', 4)
    reprs = [repr(obj).split('\n') for obj in objs]
    print (adjoin(space, *reprs))
    print()
    return

# %%
def list_files(directory):
    files = []
    counter = 0
    for f in listdir(directory):
        if f.endswith('.' + "csv"):
            files.append(f)
            counter = counter + 1
    print ("CSV Files: " + str(counter))
    return files

# %%
directory_FB = "Data/Balanced/Clean_Data_FB/" 
directory_Mean = "Data/Balanced/Clean_Data_Mean/"
directory_NaN = "Data/Balanced/Clean_Data_NaN/"

# %% [markdown]
# We have a problem with following
# * bpCuffDiastolic.csv
# * bpCuffMean.csv
# * bpCuffSystolic.csv
# * glucometer.csv
# * skinTemperature.csv
# * hrAlarmLow.csv
# * respRate.csv

# %%
bad_neonates = [100044, 100062, 100081, 159338, 155826, 187822, 145130, 146110, 120546, 157469]

# %% [markdown]
# ### Functions

# %%
def drop_defected_neonates_rows(filename): 
    df = pd.read_csv(filename) 
    
    for neonate in bad_neonates: 
        drop_list = []

        i = df[df['HADM_ID'] == neonate].index                             

        # Appending indeces to drop list  
        drop_list.append(i) 

        ## droping rows 
        for i in drop_list: 
            df.drop(i, axis=0, inplace=True)
        
    df.to_csv(filename, index=False) 
        
    print('----------------------------------') 
    print("File: " + filename) 
        
    print ("Unique Neonates: " + str(df['HADM_ID'].nunique()))
        
    side_by_side(df.isnull().sum(), df.count())

# %% [markdown]
# ### Load Data

# %%
fb_files   = list_files(directory_FB) 
mean_files = list_files(directory_Mean) 
nan_files  = list_files(directory_NaN) 

for file in fb_files: 
    drop_defected_neonates_rows(directory_FB + file)
    drop_defected_neonates_rows(directory_Mean + file)
    drop_defected_neonates_rows(directory_NaN + file)
# Out:
# CSV Files: 13
# CSV Files: 13
# CSV Files: 13
# ----------------------------------
# File: Data/Balanced/Clean_Data_FB/bpCuffDiastolic.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_Mean/bpCuffDiastolic.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_NaN/bpCuffDiastolic.csv
# Unique Neonates: 3135
# subject_id        0    subject_id    75240
# HADM_ID           0    HADM_ID       75240
# CHARTTIME         0    CHARTTIME     75240
# VALUENUM      51386    VALUENUM      23854
# dtype: int64           dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_FB/bpCuffMean.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_Mean/bpCuffMean.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_NaN/bpCuffMean.csv
# Unique Neonates: 3135
# subject_id        0    subject_id    75231
# HADM_ID           0    HADM_ID       75231
# CHARTTIME         0    CHARTTIME     75231
# VALUENUM      51363    VALUENUM      23868
# dtype: int64           dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_FB/bpCuffSystolic.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_Mean/bpCuffSystolic.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_NaN/bpCuffSystolic.csv
# Unique Neonates: 3135
# subject_id        0    subject_id    75228
# HADM_ID           0    HADM_ID       75228
# CHARTTIME         0    CHARTTIME     75228
# VALUENUM      51386    VALUENUM      23842
# dtype: int64           dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_FB/glucometer.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_Mean/glucometer.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_NaN/glucometer.csv
# Unique Neonates: 3135
# subject_id        0    subject_id    75222
# HADM_ID           0    HADM_ID       75222
# CHARTTIME         0    CHARTTIME     75222
# VALUENUM      60271    VALUENUM      14951
# dtype: int64           dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_FB/heartRate.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_Mean/heartRate.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_NaN/heartRate.csv
# Unique Neonates: 3135
# subject_id       0    subject_id    75240
# HADM_ID          0    HADM_ID       75240
# CHARTTIME        0    CHARTTIME     75240
# VALUENUM      4317    VALUENUM      70923
# dtype: int64          dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_FB/hrAlarmHigh.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_Mean/hrAlarmHigh.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_NaN/hrAlarmHigh.csv
# Unique Neonates: 3135
# subject_id       0    subject_id    75240
# HADM_ID          0    HADM_ID       75240
# CHARTTIME        0    CHARTTIME     75240
# VALUENUM      5818    VALUENUM      69422
# dtype: int64          dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_FB/hrAlarmLow.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_Mean/hrAlarmLow.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_NaN/hrAlarmLow.csv
# Unique Neonates: 3135
# subject_id       0    subject_id    75240
# HADM_ID          0    HADM_ID       75240
# CHARTTIME        0    CHARTTIME     75240
# VALUENUM      5893    VALUENUM      69347
# dtype: int64          dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_FB/respRate.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_Mean/respRate.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_NaN/respRate.csv
# Unique Neonates: 3135
# subject_id       0    subject_id    75240
# HADM_ID          0    HADM_ID       75240
# CHARTTIME        0    CHARTTIME     75240
# VALUENUM      5944    VALUENUM      69296
# dtype: int64          dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_FB/sao2.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_Mean/sao2.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_NaN/sao2.csv
# Unique Neonates: 3135
# subject_id       0    subject_id    75240
# HADM_ID          0    HADM_ID       75240
# CHARTTIME        0    CHARTTIME     75240
# VALUENUM      4522    VALUENUM      70718
# dtype: int64          dtype: int64
# ----------------------------------
# File: Data/Balanced/Clean_Data_FB/sao2AlarmHigh.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_Mean/sao2AlarmHigh.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_NaN/sao2AlarmHigh.csv
# Unique Neonates: 3135
# subject_id       0    subject_id    75240
# HADM_ID          0    HADM_ID       75240
# CHARTTIME        0    CHARTTIME     75240
# VALUENUM      5980    VALUENUM      69260
# dtype: int64          dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_FB/sao2AlarmLow.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_Mean/sao2AlarmLow.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_NaN/sao2AlarmLow.csv
# Unique Neonates: 3135
# subject_id       0    subject_id    75240
# HADM_ID          0    HADM_ID       75240
# CHARTTIME        0    CHARTTIME     75240
# VALUENUM      5954    VALUENUM      69286
# dtype: int64          dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_FB/skinTemperature.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_Mean/skinTemperature.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_NaN/skinTemperature.csv
# Unique Neonates: 3135
# subject_id        0    subject_id    75240
# HADM_ID           0    HADM_ID       75240
# CHARTTIME         0    CHARTTIME     75240
# VALUENUM      16559    VALUENUM      58681
# dtype: int64           dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_FB/temperature.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_Mean/temperature.csv
# Unique Neonates: 3135
# subject_id    0    subject_id    75240
# HADM_ID       0    HADM_ID       75240
# CHARTTIME     0    CHARTTIME     75240
# VALUENUM      0    VALUENUM      75240
# dtype: int64       dtype: int64
#
# ----------------------------------
# File: Data/Balanced/Clean_Data_NaN/temperature.csv
# Unique Neonates: 3135
# subject_id        0    subject_id    75240
# HADM_ID           0    HADM_ID       75240
# CHARTTIME         0    CHARTTIME     75240
# VALUENUM      16365    VALUENUM      58875
# dtype: int64           dtype: int64
