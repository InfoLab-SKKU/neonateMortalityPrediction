# %% [markdown]
# ## Converting Time Series Data into Single Value Data
#
# - Firuz Juraev

# %%
import pandas as pd 
from os import path
import numpy as np 
import math

# %%
def side_by_side(*objs, **kwds):
    from pandas.io.formats.printing import adjoin
    space = kwds.get('space', 4)
    reprs = [repr(obj).split('\n') for obj in objs]
    print (adjoin(space, *reprs))
    print()
    return

# %%
data = pd.read_csv('NeonatesTimeSeries_NaN.csv')

# %%
data.head()
# Out:
#    subject_id  HADM_ID  CHARTTIME  bpCuffDiastolic  bpCuffMean  \
# 0       14509   100029          0             43.0        49.0
# 1       14509   100029          1              NaN         NaN
# 2       14509   100029          2              NaN         NaN
# 3       14509   100029          3             39.0        45.0
# 4       14509   100029          4              NaN         NaN
#
#    bpCuffSystolic  glucometer  heartRate  hrAlarmHigh  hrAlarmLow  respRate  \
# 0            59.0        61.0      154.0        200.0        80.0      56.0
# 1             NaN         NaN      140.0        200.0        80.0      44.0
# 2             NaN         NaN      148.0        200.0        80.0      40.0
# 3            55.0         NaN      136.0        200.0        80.0      40.0
# 4             NaN         NaN      132.0        200.0        80.0      56.0
#
#     sao2  sao2AlarmHigh  sao2AlarmLow  skinTemperature  temperature        LOS
# 0   95.0          100.0          90.0        36.500000    36.599998  15.006944
# 1   99.0          100.0          90.0        36.599998    36.599998  15.006944
# 2   98.0          100.0          90.0        36.799999          NaN  15.006944
# 3  100.0          100.0          90.0              NaN    36.599998  15.006944
# 4  100.0          100.0          90.0        36.700001          NaN  15.006944

# %% [markdown]
# ## Converting Function

# %%
def compress(column_name, subject_id, column_values):
    if not math.isnan(column_values.std()): 
        std_value = column_values.std()
    else: 
        std_value = 0
    mean_value = column_values.mean()
    median_value = column_values.median()
    if len(column_values.mode().values) > 0: 
        mode_value = column_values.mode().values[0]
    else: 
        mode_value = np.nan 
     
    
    # create columns     
    slice_columns = ["subject_id", 
               (column_name + "_mean"),
               (column_name + "_median"),
               (column_name + "_mode"), 
               (column_name + "_std")]
    
    # Creating a row 
    df = pd.DataFrame(columns = slice_columns)
    df.loc[0] = [subject_id, mean_value, median_value, mode_value, std_value]
    
    return df

# %%
def converter(df, filename): 
    df_columns = data.columns.to_list()[3:-1]
    
    parts_list = [] 
    
    for col in df_columns: 
        part = compress(col, df['subject_id'].iloc[0], df[col])
        parts_list.append(part) 
    
    join_dfs = parts_list[0] 
    
    for i in range(1, len(parts_list)): 
        join_dfs = pd.merge(join_dfs, parts_list[i], on='subject_id', how='inner') 
    
    if path.exists(filename): 
        join_dfs.to_csv(filename, mode='a', header=False, index=False)
    else: 
        join_dfs.to_csv(filename, index=False, header=True)

# %%
df_columns.to_list()[3:-1]
# Out:
# ['bpCuffDiastolic',
#  'bpCuffMean',
#  'bpCuffSystolic',
#  'glucometer',
#  'heartRate',
#  'hrAlarmHigh',
#  'hrAlarmLow',
#  'respRate',
#  'sao2',
#  'sao2AlarmHigh',
#  'sao2AlarmLow',
#  'skinTemperature',
#  'temperature']

# %%
# finding unique ids 
unique_subjects_ids = data['subject_id'].unique() 

# Converting 
for i in range(0, len(unique_subjects_ids)): 
    converter(data.loc[data['subject_id'] == unique_subjects_ids[i]], 'test3.csv')

# %%
test = pd.read_csv('test3.csv')
test.head(10)
# Out:
#    subject_id  bpCuffDiastolic_mean  bpCuffDiastolic_median  \
# 0     14509.0             36.250000                    37.5
# 1     11221.0             36.583333                    35.0
# 2     11190.0             36.400000                    36.0
# 3     11002.0             39.500000                    39.0
# 4      2507.0             27.428571                    30.0
# 5     28624.0             38.714286                    39.0
# 6     28585.0             28.833333                    25.0
# 7     21221.0             39.333333                    41.0
# 8      8176.0             28.333333                    27.5
# 9     13028.0             29.800000                    28.0
#
#    bpCuffDiastolic_mode  bpCuffDiastolic_std  bpCuffMean_mean  \
# 0                  27.0             6.800735        44.250000
# 1                  35.0             7.988670        41.708333
# 2                  35.0             4.247875        48.000000
# 3                  38.0             3.781534        54.666667
# 4                  30.0             4.894117        34.714286
# 5                  24.0            10.889051        51.285714
# 6                  24.0             7.413951        42.166667
# 7                  35.0             3.785939        51.333333
# 8                  23.0             4.412105        43.500000
# 9                  25.0             5.308274        41.400000
#
#    bpCuffMean_median  bpCuffMean_mode  bpCuffMean_std  bpCuffSystolic_mean  \
# 0               45.5             37.0        5.123475            56.500000
# 1               39.5             35.0        7.363123            52.625000
# 2               48.0             48.0        4.690416            74.100000
# 3               55.0             49.0        3.881580            72.333333
# 4               35.0             36.0        1.496026            49.142857
# 5               48.0             48.0        7.158079            74.285714
# 6               38.0             36.0        8.542053            65.833333
# 7               53.0             47.0        3.785939            73.666667
# 8               43.0             43.0        5.431390            65.333333
# 9               38.5             37.0        6.703233            56.100000
#
#    ...  sao2AlarmLow_mode  sao2AlarmLow_std  skinTemperature_mean  \
# 0  ...               90.0          0.000000             36.480000
# 1  ...               90.0          1.062367             35.983334
# 2  ...               87.0          0.000000             35.826087
# 3  ...               90.0          0.000000             36.124999
# 4  ...               87.0          0.000000             36.413044
# 5  ...               87.0          0.000000             35.912500
# 6  ...               90.0          1.659404             36.412500
# 7  ...               90.0          0.000000             36.200000
# 8  ...               87.0          0.000000             35.295833
# 9  ...               87.0          0.000000             36.525000
#
#    skinTemperature_median  skinTemperature_mode  skinTemperature_std  \
# 0               36.400002             36.299999             0.259670
# 1               36.000000             36.000000             0.261545
# 2               35.799999             36.000000             0.157300
# 3               36.199999             36.299999             0.236291
# 4               36.400002             36.200001             0.226242
# 5               35.850000             35.700001             0.313899
# 6               36.500000             36.500000             0.174643
# 7               36.200001             36.200001             0.081650
# 8               35.250000             35.000000             0.439841
# 9               36.650000             36.700001             0.287229
#
#    temperature_mean  temperature_median  temperature_mode  temperature_std
# 0         36.292857           36.299999         36.299999         0.289466
# 1         35.616666           35.599998         35.599998         0.618319
# 2         35.599998           35.599998         35.599998         0.000000
# 3         36.000000           36.000000         35.599998         0.365150
# 4         36.311111           36.299999         36.299999         0.152966
# 5         36.025000           35.950001         36.000000         0.313812
# 6         36.357143           36.500000         36.500000         0.234404
# 7         36.000000           36.000000         36.000000         0.000000
# 8         35.579167           35.500000         35.500000         0.480923
# 9         36.190909           36.200001         36.200001         0.104447
#
# [10 rows x 53 columns]

# %%
side_by_side(test.isnull().sum(), test.count())
# Out:
# subject_id                0    subject_id                3135
# bpCuffDiastolic_mean      0    bpCuffDiastolic_mean      3135
# bpCuffDiastolic_median    0    bpCuffDiastolic_median    3135
# bpCuffDiastolic_mode      0    bpCuffDiastolic_mode      3135
# bpCuffDiastolic_std       0    bpCuffDiastolic_std       3135
# bpCuffMean_mean           0    bpCuffMean_mean           3135
# bpCuffMean_median         0    bpCuffMean_median         3135
# bpCuffMean_mode           0    bpCuffMean_mode           3135
# bpCuffMean_std            0    bpCuffMean_std            3135
# bpCuffSystolic_mean       0    bpCuffSystolic_mean       3135
# bpCuffSystolic_median     0    bpCuffSystolic_median     3135
# bpCuffSystolic_mode       0    bpCuffSystolic_mode       3135
# bpCuffSystolic_std        0    bpCuffSystolic_std        3135
# glucometer_mean           1    glucometer_mean           3134
# glucometer_median         1    glucometer_median         3134
# glucometer_mode           1    glucometer_mode           3134
# glucometer_std            0    glucometer_std            3135
# heartRate_mean            0    heartRate_mean            3135
# heartRate_median          0    heartRate_median          3135
# heartRate_mode            0    heartRate_mode            3135
# heartRate_std             0    heartRate_std             3135
# hrAlarmHigh_mean          0    hrAlarmHigh_mean          3135
# hrAlarmHigh_median        0    hrAlarmHigh_median        3135
# hrAlarmHigh_mode          0    hrAlarmHigh_mode          3135
# hrAlarmHigh_std           0    hrAlarmHigh_std           3135
# hrAlarmLow_mean           0    hrAlarmLow_mean           3135
# hrAlarmLow_median         0    hrAlarmLow_median         3135
# hrAlarmLow_mode           0    hrAlarmLow_mode           3135
# hrAlarmLow_std            0    hrAlarmLow_std            3135
# respRate_mean             0    respRate_mean             3135
# respRate_median           0    respRate_median           3135
# respRate_mode             0    respRate_mode             3135
# respRate_std              0    respRate_std              3135
# sao2_mean                 0    sao2_mean                 3135
# sao2_median               0    sao2_median               3135
# sao2_mode                 0    sao2_mode                 3135
# sao2_std                  0    sao2_std                  3135
# sao2AlarmHigh_mean        0    sao2AlarmHigh_mean        3135
# sao2AlarmHigh_median      0    sao2AlarmHigh_median      3135
# sao2AlarmHigh_mode        0    sao2AlarmHigh_mode        3135
# sao2AlarmHigh_std         0    sao2AlarmHigh_std         3135
# sao2AlarmLow_mean         0    sao2AlarmLow_mean         3135
# sao2AlarmLow_median       0    sao2AlarmLow_median       3135
# sao2AlarmLow_mode         0    sao2AlarmLow_mode         3135
# sao2AlarmLow_std          0    sao2AlarmLow_std          3135
# skinTemperature_mean      0    skinTemperature_mean      3135
# skinTemperature_median    0    skinTemperature_median    3135
# skinTemperature_mode      0    skinTemperature_mode      3135
# skinTemperature_std       0    skinTemperature_std       3135
# temperature_mean          0    temperature_mean          3135
# temperature_median        0    temperature_median        3135
# temperature_mode          0    temperature_mode          3135
# temperature_std           0    temperature_std           3135
# dtype: int64                   dtype: int64
