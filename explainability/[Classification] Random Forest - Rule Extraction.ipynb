# %% [markdown]
# ## <center><font color='green'> Random Forest Classifier - Rule Extraction
#
# > https://stackoverflow.com/questions/50600290/how-extraction-decision-rules-of-random-forest-in-python

# %% [markdown]
# > Random Forests are a combination of tree predictors where each tree depends on the values of a random vector sampled independently with the same distribution for all trees in the forest. The basic principle is that a group of “weak learners” can come together to form a “strong learner”. Random Forests are a wonderful tool for making predictions considering they do not overfit because of the law of large numbers. Introducing the right kind of randomness makes them accurate classifiers and regressors.

# %% [markdown]
# > Random forest, like its name implies, consists of a large number of individual decision trees that operate as an ensemble. Each individual tree in the random forest spits out a class prediction and the class with the most votes becomes our model’s prediction (see figure below).

# %% [markdown]
# <img src="./images/random_forest.jpeg" align="left" width=400>

# %%
import numpy
from sklearn.model_selection import train_test_split
from sklearn import metrics, datasets, ensemble

# %%
import pandas as pd 
import numpy as np
import matplotlib.pylab as plt 

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import mutual_info_classif
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from rulefit import RuleFit

# %% [markdown]
# #### <font color='purple'> Load dataset

# %%
train_dataset_upsampled = pd.read_csv("dataset/Resampled_neonates_train_data_4.csv")
test_dataset_upsampled = pd.read_csv("dataset/Resampled_neonates_test_data_4.csv")

X_train = train_dataset_upsampled.drop(["DEAD"], axis=1) 
y_train = train_dataset_upsampled["DEAD"]

X_test = test_dataset_upsampled.drop(["DEAD"], axis=1) 
y_test = test_dataset_upsampled["DEAD"]

# %% [markdown]
# #### <font color='purple'> Normalizing

# %%
columns = X_train.columns.to_list() 

Min_max_scaler = MinMaxScaler().fit(X_train)

## Scaling 
X_train_mm_scaled = Min_max_scaler.transform(X_train)
X_test_mm_scaled = Min_max_scaler.transform(X_test)

## Numpy Array to DataFrame 
df_train_mm_scaled = pd.DataFrame(X_train_mm_scaled, columns = columns)
df_test_mm_scaled = pd.DataFrame(X_test_mm_scaled, columns = columns)

# %% [markdown]
# #### <font color='purple'> Feature Selection

# %%
tain_mm_scaled_df = df_train_mm_scaled[:]
tain_mm_scaled_df["DEAD"] = y_train 

test_mm_scaled_df = df_test_mm_scaled[:] 
test_mm_scaled_df["DEAD"] = y_test


importances = mutual_info_classif(df_train_mm_scaled, y_train)
feat_importance = pd.Series(importances, tain_mm_scaled_df.columns[0:len(tain_mm_scaled_df.columns)-1])
    
feat_importance = feat_importance.sort_values(ascending=False)
    
selected_features = feat_importance[:30]
selected_features_list_mm_scaled = selected_features.index.to_list()


tain_mm_scaled_df[selected_features_list_mm_scaled].head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-dd6cd545ed26> in <module>
# ----> 1 tain_mm_scaled_df = df_train_mm_scaled[:]
#       2 tain_mm_scaled_df["DEAD"] = y_train
#       3
#       4 test_mm_scaled_df = df_test_mm_scaled[:]
#       5 test_mm_scaled_df["DEAD"] = y_test
#
# NameError: name 'df_train_mm_scaled' is not defined

# %%
X_train_mm = X_train[selected_features_list_mm_scaled][:] ## using only selected features 
X_test_mm = X_test[selected_features_list_mm_scaled][:]   ## using only selected features

# %%
X_train_mm = df_train_mm_scaled[selected_features_list_mm_scaled][:] ## using only selected features 
X_test_mm = df_test_mm_scaled[selected_features_list_mm_scaled][:]   ## using only selected features

# %%
X_train_mm.rename({'temperature_mean': 'Temperature (mean)', 
           'temperature_var': 'Temperature (variance)', 
           'temperature_std': 'Temperature (std)',  
           'respRate_std': 'Respiratory Rate (std)', 
           'respRate_var': 'Respiratory Rate (variance)',
           'respRate_mean': 'Respiratory Rate (mean)', 
           'skinTemperature_var': 'Skin Temperature (variance)', 
           'skinTemperature_std': 'Skin Temperature (std)',
           'skinTemperature_mean': 'Skin Temperature (mean)',
           'heartRate_std': 'Heart Rate (std)', 
           'heartRate_var': 'Heart Rate (variance)',
           'heartRate_mean': 'Heart Rate (mena)',
           'bpCuffMean_std': 'Blood Pressure Cuff Mean (std)', 
           'bpCuffMean_var': 'Blood Pressure Cuff Mean (variance)',
           'bpCuffMean_mean': 'Blood Pressure Cuff Mean (mean)',
           'bpCuffSystolic_std': 'Blood Pressure Cuff Systolic (std)',
           'bpCuffSystolic_var': 'Blood Pressure Cuff Systolic (variance)',
           'bpCuffSystolic_mean': 'Blood Pressure Cuff Systolic (mean)',
           'bpCuffDiastolic_var': 'Blood Pressure Cuff Diastolic (variance)',
           'bpCuffDiastolic_std': 'Blood Pressure Cuff Diastolic (std)',
           'bpCuffDiastolic_mean': 'Blood Pressure Cuff Diastolic (mean)',
           'sao2_var': 'SaO2 (variance)', 
           'sao2_std': 'SaO2 (std)',
           'sao2_mean': 'SaO2 (mean)',
           'glucometer_std': 'Glucometer (std)', 
           'glucometer_var': 'Glucometer (variance)', 
           'glucometer_mean': 'Glucometer (mean)',
           'BIRTH_WEIGHT': 'Birth Weight (kg)', 
           'PLATELET': 'Platelet',
           'D10W_SUM': 'Sum of D10W (input)'}, axis=1, inplace=True)

# %%
X_test_mm.rename({'temperature_mean': 'Temperature (mean)', 
           'temperature_var': 'Temperature (variance)', 
           'temperature_std': 'Temperature (std)',  
           'respRate_std': 'Respiratory Rate (std)', 
           'respRate_var': 'Respiratory Rate (variance)',
           'respRate_mean': 'Respiratory Rate (mean)', 
           'skinTemperature_var': 'Skin Temperature (variance)', 
           'skinTemperature_std': 'Skin Temperature (std)',
           'skinTemperature_mean': 'Skin Temperature (mean)',
           'heartRate_std': 'Heart Rate (std)', 
           'heartRate_var': 'Heart Rate (variance)',
           'heartRate_mean': 'Heart Rate (mena)',
           'bpCuffMean_std': 'Blood Pressure Cuff Mean (std)', 
           'bpCuffMean_var': 'Blood Pressure Cuff Mean (variance)',
           'bpCuffMean_mean': 'Blood Pressure Cuff Mean (mean)',
           'bpCuffSystolic_std': 'Blood Pressure Cuff Systolic (std)',
           'bpCuffSystolic_var': 'Blood Pressure Cuff Systolic (variance)',
           'bpCuffSystolic_mean': 'Blood Pressure Cuff Systolic (mean)',
           'bpCuffDiastolic_var': 'Blood Pressure Cuff Diastolic (variance)',
           'bpCuffDiastolic_std': 'Blood Pressure Cuff Diastolic (std)',
           'bpCuffDiastolic_mean': 'Blood Pressure Cuff Diastolic (mean)',
           'sao2_var': 'SaO2 (variance)', 
           'sao2_std': 'SaO2 (std)',
           'sao2_mean': 'SaO2 (mean)',
           'glucometer_std': 'Glucometer (std)', 
           'glucometer_var': 'Glucometer (variance)', 
           'glucometer_mean': 'Glucometer (mean)',
           'BIRTH_WEIGHT': 'Birth Weight (kg)', 
           'PLATELET': 'Platelet',
           'D10W_SUM': 'Sum of D10W (input)'}, axis=1, inplace=True)

# %%
X_train_mm['DEAD'] = y_train
X_train_mm.to_csv("train_classification_dataset.csv", index=False)

# %%
X_train_mm
# Out:
#       Temperature (mean)  Respiratory Rate (std)  Respiratory Rate (variance)  \
# 0              36.165218               14.233050                   202.579710
# 1              35.658334               19.684283                   387.471014
# 2              35.608333               19.811430                   392.492754
# 3              36.004999               19.231428                   369.847826
# 4              36.158334               14.442289                   208.579710
# ...                  ...                     ...                          ...
# 4315           36.017391               13.774320                   189.731884
# 4316           36.062500                5.727681                    32.806324
# 4317           36.017391               13.774320                   189.731884
# 4318           36.244444                7.701700                    59.316176
# 4319           36.791304                0.000000                     0.000000
#
#       Skin Temperature (variance)  Skin Temperature (std)  Heart Rate (std)  \
# 0                        0.133913                0.365941         10.892675
# 1                        0.055958                0.236555         13.269776
# 2                        0.094493                0.307397          8.722368
# 3                        0.151869                0.389703         11.852964
# 4                        0.011884                0.109014         11.374313
# ...                           ...                     ...               ...
# 4315                     0.008775                0.093673          5.496870
# 4316                     0.025634                0.160107         11.760903
# 4317                     0.008775                0.093673          5.496870
# 4318                     0.039015                0.197522          8.833426
# 4319                     0.304275                0.551611         15.066459
#
#       Heart Rate (variance)  Blood Pressure Cuff Mean (variance)  SaO2 (std)  \
# 0                118.650362                            23.982143    2.686183
# 1                176.086957                             9.142857    2.222660
# 2                 76.079710                            49.839286    3.583375
# 3                140.492754                            41.333333    2.496374
# 4                129.375000                            74.564103    0.916831
# ...                     ...                                  ...         ...
# 4315              30.215580                           153.300000    2.626258
# 4316             138.318841                             2.250000    1.888178
# 4317              30.215580                           153.300000    2.626258
# 4318              78.029412                           142.000000    1.944071
# 4319             226.998188                            97.809524    2.185260
#
#       SaO2 (variance)  ...  Blood Pressure Cuff Systolic (mean)  \
# 0            7.215580  ...                            54.600000
# 1            4.940217  ...                            58.428571
# 2           12.840580  ...                            61.375000
# 3            6.231884  ...                            64.000000
# 4            0.840580  ...                            65.200000
# ...               ...  ...                                  ...
# 4315         6.897233  ...                            67.600000
# 4316         3.565217  ...                            60.500000
# 4317         6.897233  ...                            67.600000
# 4318         3.779412  ...                            61.428571
# 4319         4.775362  ...                            51.833333
#
#       Blood Pressure Cuff Diastolic (mean)  Temperature (std)  \
# 0                                31.200000           0.503270
# 1                                32.714286           0.246645
# 2                                30.375000           0.270131
# 3                                43.000000           0.374833
# 4                                38.500000           0.190917
# ...                                    ...                ...
# 4315                             35.400000           0.049103
# 4316                             33.250000           0.087539
# 4317                             35.400000           0.049103
# 4318                             37.285714           0.328295
# 4319                             37.800000           0.513378
#
#       Glucometer (mean)  Temperature (variance)  SaO2 (mean)  \
# 0             85.285714                0.253280    95.791667
# 1             76.666667                0.060834    97.375000
# 2             93.800000                0.072971    96.666667
# 3             78.666667                0.140500    97.166667
# 4            102.166667                0.036449    99.333333
# ...                 ...                     ...          ...
# 4315         111.800000                0.002411    93.521739
# 4316          58.600000                0.007663    98.000000
# 4317         111.800000                0.002411    93.521739
# 4318          58.500000                0.107777    98.176471
# 4319          89.000000                0.263557    94.416667
#
#       Blood Pressure Cuff Mean (mean)  Platelet  Sum of D10W (input)  DEAD
# 0                           40.625000     193.0           115.999999     0
# 1                           42.142857     258.0           157.600001     0
# 2                           40.875000     245.0           159.600000     0
# 3                           48.333333     287.0           189.000001     0
# 4                           42.307692     295.0           187.900000     0
# ...                               ...       ...                  ...   ...
# 4315                        45.600000     255.0            26.500000     1
# 4316                        43.750000     380.0           122.200000     1
# 4317                        45.600000     255.0            26.500000     1
# 4318                        42.000000     233.0            76.699999     1
# 4319                        39.142857     247.0             1.710000     1
#
# [4320 rows x 31 columns]

# %% [markdown]
# #### <font color='purple'> Model and Fit

# %%
model_rf = RandomForestClassifier(criterion='gini', n_estimators=80, max_depth=2)

model_rf.fit(X_train_mm, y_train)

print(f'Random Forest Classifier accuracy: {round(model_rf.score(X_test_mm, y_test), 3)}')
# Out:
# Random Forest Classifier accuracy: 0.957

# %%
def print_decision_rules(rf, columns):

    for tree_idx, est in enumerate(rf.estimators_):
        tree = est.tree_
        assert tree.value.shape[1] == 1 # no support for multi-output

        print('TREE: {}'.format(tree_idx))

        iterator = enumerate(zip(tree.children_left, tree.children_right, tree.feature, tree.threshold, tree.value))
        for node_idx, data in iterator:
            left, right, feature, th, value = data

            # left: index of left child (if any)
            # right: index of right child (if any)
            # feature: index of the feature to check
            # th: the threshold to compare against
            # value: values associated with classes            

            # for classifier, value is 0 except the index of the class to return
            class_idx = numpy.argmax(value[0])

            if left == -1 and right == -1:
                print('{} LEAF: return class={}'.format(node_idx, class_idx))
            else:
                print('{} NODE: if [{}] < {} then next={} else next={}'.format(node_idx, columns[feature], th, left, right))

# %%
model_rf.fit(X_train_mm, y_train)

print_decision_rules(model_rf, X_train_mm.columns.to_list())
# Out:
# TREE: 0
# 0 NODE: if [Temperature (mean)] < 36.01213264465332 then next=1 else next=4
# 1 NODE: if [Blood Pressure Cuff Systolic (mean)] < 79.96666717529297 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [SaO2 (std)] < 1.8879384398460388 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 1
# 0 NODE: if [Respiratory Rate (std)] < 6.013504981994629 then next=1 else next=4
# 1 NODE: if [Skin Temperature (variance)] < 0.013913213275372982 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Birth Weight (kg)] < 1.2774999737739563 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 2
# 0 NODE: if [SaO2 (variance)] < 24.473731994628906 then next=1 else next=4
# 1 NODE: if [SaO2 (mean)] < 95.47916793823242 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Birth Weight (kg)] < 2.575000047683716 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 3
# 0 NODE: if [Temperature (mean)] < 36.01213264465332 then next=1 else next=4
# 1 NODE: if [Blood Pressure Cuff Mean (std)] < 15.655097007751465 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [SaO2 (std)] < 1.8879384398460388 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 4
# 0 NODE: if [Blood Pressure Cuff Systolic (mean)] < 55.42016792297363 then next=1 else next=4
# 1 NODE: if [Blood Pressure Cuff Mean (std)] < 6.22415828704834 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Blood Pressure Cuff Mean (variance)] < 141.3095245361328 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 5
# 0 NODE: if [SaO2 (mean)] < 94.4375 then next=1 else next=4
# 1 NODE: if [SaO2 (std)] < 5.279633522033691 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=1
# 4 NODE: if [Skin Temperature (mean)] < 36.49791717529297 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 6
# 0 NODE: if [Temperature (std)] < 0.5200751423835754 then next=1 else next=4
# 1 NODE: if [Skin Temperature (mean)] < 36.04701614379883 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 LEAF: return class=0
# TREE: 7
# 0 NODE: if [Temperature (mean)] < 36.01213264465332 then next=1 else next=4
# 1 NODE: if [Blood Pressure Cuff Mean (std)] < 15.333180904388428 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Blood Pressure Cuff Diastolic (mean)] < 38.035715103149414 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 8
# 0 NODE: if [SaO2 (mean)] < 92.3125 then next=1 else next=4
# 1 NODE: if [Blood Pressure Cuff Mean (mean)] < 52.0625 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Respiratory Rate (mean)] < 34.331932067871094 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 9
# 0 NODE: if [SaO2 (mean)] < 92.3125 then next=1 else next=4
# 1 NODE: if [Sum of D10W (input)] < 119.95000076293945 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Sum of D10W (input)] < 35.14999961853027 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 10
# 0 NODE: if [Birth Weight (kg)] < 1.3125 then next=1 else next=4
# 1 NODE: if [Respiratory Rate (mean)] < 41.779762268066406 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=1
# 4 NODE: if [SaO2 (std)] < 4.946933031082153 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 11
# 0 NODE: if [Birth Weight (kg)] < 1.3149999976158142 then next=1 else next=4
# 1 NODE: if [SaO2 (mean)] < 96.04861068725586 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Blood Pressure Cuff Mean (variance)] < 141.64444732666016 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 12
# 0 NODE: if [Heart Rate (mena)] < 155.77083587646484 then next=1 else next=4
# 1 NODE: if [SaO2 (mean)] < 93.22916793823242 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Blood Pressure Cuff Systolic (std)] < 6.306464195251465 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 13
# 0 NODE: if [Blood Pressure Cuff Systolic (std)] < 8.139556407928467 then next=1 else next=4
# 1 NODE: if [SaO2 (mean)] < 92.3125 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Blood Pressure Cuff Systolic (mean)] < 55.45588302612305 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 14
# 0 NODE: if [Blood Pressure Cuff Systolic (std)] < 8.1293044090271 then next=1 else next=4
# 1 NODE: if [Temperature (mean)] < 36.37708282470703 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Respiratory Rate (variance)] < 60.396183013916016 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=1
# TREE: 15
# 0 NODE: if [SaO2 (std)] < 4.946933031082153 then next=1 else next=4
# 1 NODE: if [Skin Temperature (mean)] < 36.422916412353516 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Blood Pressure Cuff Systolic (mean)] < 58.01250076293945 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=1
# TREE: 16
# 0 NODE: if [SaO2 (mean)] < 94.4375 then next=1 else next=4
# 1 NODE: if [Birth Weight (kg)] < 2.5600000619888306 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Respiratory Rate (variance)] < 70.78804397583008 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 17
# 0 NODE: if [Sum of D10W (input)] < 62.114999771118164 then next=1 else next=4
# 1 NODE: if [SaO2 (std)] < 2.109966516494751 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Blood Pressure Cuff Systolic (variance)] < 248.47618865966797 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 18
# 0 NODE: if [SaO2 (variance)] < 23.912137985229492 then next=1 else next=4
# 1 NODE: if [Birth Weight (kg)] < 1.0675000548362732 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Temperature (mean)] < 36.00625038146973 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 19
# 0 NODE: if [SaO2 (mean)] < 92.3125 then next=1 else next=4
# 1 NODE: if [Skin Temperature (mean)] < 36.041866302490234 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Heart Rate (mena)] < 155.75 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 20
# 0 NODE: if [Temperature (mean)] < 36.01213264465332 then next=1 else next=4
# 1 NODE: if [Blood Pressure Cuff Diastolic (std)] < 17.724960327148438 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [SaO2 (variance)] < 3.5643116235733032 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 21
# 0 NODE: if [SaO2 (mean)] < 92.3125 then next=1 else next=4
# 1 NODE: if [Skin Temperature (std)] < 0.1142757348716259 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Respiratory Rate (variance)] < 59.40354347229004 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 22
# 0 NODE: if [SaO2 (mean)] < 92.3125 then next=1 else next=4
# 1 NODE: if [Blood Pressure Cuff Systolic (mean)] < 66.35714340209961 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Blood Pressure Cuff Mean (mean)] < 39.16025733947754 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 23
# 0 NODE: if [Blood Pressure Cuff Systolic (mean)] < 56.08124923706055 then next=1 else next=4
# 1 NODE: if [Skin Temperature (mean)] < 36.160661697387695 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Respiratory Rate (std)] < 8.399605751037598 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 24
# 0 NODE: if [Birth Weight (kg)] < 1.3125 then next=1 else next=4
# 1 NODE: if [SaO2 (mean)] < 96.04861068725586 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Respiratory Rate (mean)] < 35.79166793823242 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 25
# 0 NODE: if [SaO2 (mean)] < 92.33333206176758 then next=1 else next=4
# 1 NODE: if [SaO2 (std)] < 2.1982052326202393 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Birth Weight (kg)] < 1.0675000548362732 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 26
# 0 NODE: if [SaO2 (std)] < 4.946933031082153 then next=1 else next=4
# 1 NODE: if [Birth Weight (kg)] < 1.0675000548362732 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Skin Temperature (variance)] < 0.005731789919082075 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 27
# 0 NODE: if [SaO2 (mean)] < 92.3125 then next=1 else next=4
# 1 NODE: if [Sum of D10W (input)] < 126.49999618530273 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Blood Pressure Cuff Diastolic (variance)] < 92.6500015258789 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 28
# 0 NODE: if [SaO2 (mean)] < 92.33333206176758 then next=1 else next=4
# 1 NODE: if [Birth Weight (kg)] < 2.615000009536743 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Heart Rate (mena)] < 155.77083587646484 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 29
# 0 NODE: if [Blood Pressure Cuff Diastolic (mean)] < 28.08680534362793 then next=1 else next=4
# 1 NODE: if [Birth Weight (kg)] < 1.5825000405311584 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Respiratory Rate (mean)] < 38.02083396911621 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 30
# 0 NODE: if [SaO2 (std)] < 4.9442548751831055 then next=1 else next=4
# 1 NODE: if [Temperature (mean)] < 36.01702880859375 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Skin Temperature (mean)] < 36.04701614379883 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 31
# 0 NODE: if [SaO2 (mean)] < 92.33333206176758 then next=1 else next=4
# 1 NODE: if [Respiratory Rate (mean)] < 54.91666603088379 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Sum of D10W (input)] < 35.14999961853027 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 32
# 0 NODE: if [Respiratory Rate (mean)] < 37.1875 then next=1 else next=4
# 1 NODE: if [SaO2 (mean)] < 98.19934463500977 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Birth Weight (kg)] < 1.2774999737739563 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 33
# 0 NODE: if [SaO2 (std)] < 4.946933031082153 then next=1 else next=4
# 1 NODE: if [Respiratory Rate (std)] < 8.393298625946045 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Skin Temperature (variance)] < 0.009977232199162245 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 34
# 0 NODE: if [Respiratory Rate (variance)] < 36.16231918334961 then next=1 else next=4
# 1 NODE: if [SaO2 (mean)] < 98.125 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [SaO2 (std)] < 4.9442548751831055 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 35
# 0 NODE: if [Sum of D10W (input)] < 62.06500053405762 then next=1 else next=4
# 1 NODE: if [SaO2 (mean)] < 96.0625 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Temperature (mean)] < 35.84880828857422 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=0
# TREE: 36
# 0 NODE: if [Heart Rate (mena)] < 155.77083587646484 then next=1 else next=4
# 1 NODE: if [Respiratory Rate (mean)] < 37.25 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Respiratory Rate (mean)] < 59.75 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 37
# 0 NODE: if [Blood Pressure Cuff Systolic (mean)] < 56.07291603088379 then next=1 else next=4
# 1 NODE: if [Birth Weight (kg)] < 1.3174999952316284 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Temperature (mean)] < 36.522499084472656 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 38
# 0 NODE: if [SaO2 (std)] < 4.889027118682861 then next=1 else next=4
# 1 NODE: if [Temperature (mean)] < 36.01702880859375 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Temperature (variance)] < 0.270478293299675 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 39
# 0 NODE: if [SaO2 (std)] < 4.9442548751831055 then next=1 else next=4
# 1 NODE: if [Heart Rate (mena)] < 155.77083587646484 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [SaO2 (mean)] < 91.72793960571289 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=1
# TREE: 40
# 0 NODE: if [Temperature (mean)] < 36.01124954223633 then next=1 else next=4
# 1 NODE: if [Blood Pressure Cuff Systolic (std)] < 17.694802284240723 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Blood Pressure Cuff Mean (mean)] < 42.26785659790039 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 41
# 0 NODE: if [Heart Rate (mena)] < 155.77083587646484 then next=1 else next=4
# 1 NODE: if [Birth Weight (kg)] < 1.3149999976158142 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Respiratory Rate (mean)] < 59.75 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 42
# 0 NODE: if [Temperature (mean)] < 36.01213264465332 then next=1 else next=4
# 1 NODE: if [SaO2 (variance)] < 1.8903985619544983 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=0
# 4 NODE: if [SaO2 (mean)] < 95.47916793823242 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 43
# 0 NODE: if [Respiratory Rate (mean)] < 38.02083396911621 then next=1 else next=4
# 1 NODE: if [SaO2 (std)] < 1.4430615901947021 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Blood Pressure Cuff Systolic (mean)] < 53.1875 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 44
# 0 NODE: if [Respiratory Rate (std)] < 6.041337728500366 then next=1 else next=4
# 1 NODE: if [SaO2 (std)] < 1.3978047370910645 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Heart Rate (mena)] < 155.77083587646484 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 45
# 0 NODE: if [Sum of D10W (input)] < 76.76499938964844 then next=1 else next=4
# 1 NODE: if [Temperature (mean)] < 36.01702880859375 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Blood Pressure Cuff Systolic (variance)] < 313.125 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 46
# 0 NODE: if [Respiratory Rate (mean)] < 38.02083396911621 then next=1 else next=4
# 1 NODE: if [Temperature (mean)] < 36.016666412353516 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [SaO2 (variance)] < 4.454674959182739 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 47
# 0 NODE: if [SaO2 (std)] < 4.9442548751831055 then next=1 else next=4
# 1 NODE: if [Respiratory Rate (variance)] < 59.40354347229004 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Blood Pressure Cuff Systolic (mean)] < 66.33333206176758 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 48
# 0 NODE: if [Platelet] < 258.5 then next=1 else next=4
# 1 NODE: if [Temperature (mean)] < 36.01079559326172 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Blood Pressure Cuff Systolic (mean)] < 50.678571701049805 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 49
# 0 NODE: if [Blood Pressure Cuff Mean (mean)] < 39.16025733947754 then next=1 else next=4
# 1 NODE: if [Sum of D10W (input)] < 40.435001373291016 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [SaO2 (mean)] < 92.33333206176758 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 50
# 0 NODE: if [Sum of D10W (input)] < 76.76499938964844 then next=1 else next=4
# 1 NODE: if [Skin Temperature (mean)] < 36.04701614379883 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Blood Pressure Cuff Diastolic (std)] < 17.724960327148438 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 51
# 0 NODE: if [Blood Pressure Cuff Mean (std)] < 6.241756439208984 then next=1 else next=4
# 1 NODE: if [Birth Weight (kg)] < 1.0524999499320984 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Temperature (mean)] < 36.18564224243164 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 52
# 0 NODE: if [Skin Temperature (mean)] < 36.324039459228516 then next=1 else next=4
# 1 NODE: if [Heart Rate (mena)] < 155.75 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [SaO2 (std)] < 1.9386427998542786 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 53
# 0 NODE: if [Birth Weight (kg)] < 1.3125 then next=1 else next=4
# 1 NODE: if [Temperature (variance)] < 0.2669597864151001 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Glucometer (std)] < 51.9709415435791 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 54
# 0 NODE: if [Heart Rate (mena)] < 155.77083587646484 then next=1 else next=4
# 1 NODE: if [Birth Weight (kg)] < 1.0524999499320984 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [SaO2 (variance)] < 34.738224029541016 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=1
# TREE: 55
# 0 NODE: if [SaO2 (variance)] < 24.447463989257812 then next=1 else next=4
# 1 NODE: if [Respiratory Rate (mean)] < 34.24264717102051 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Temperature (mean)] < 36.00625038146973 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 56
# 0 NODE: if [Respiratory Rate (mean)] < 38.02083396911621 then next=1 else next=4
# 1 NODE: if [Blood Pressure Cuff Systolic (variance)] < 41.39999961853027 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=1
# 4 NODE: if [Sum of D10W (input)] < 26.699999809265137 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 57
# 0 NODE: if [Sum of D10W (input)] < 76.76499938964844 then next=1 else next=4
# 1 NODE: if [SaO2 (variance)] < 3.7701406478881836 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Blood Pressure Cuff Systolic (std)] < 17.694802284240723 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 58
# 0 NODE: if [Temperature (mean)] < 36.01213264465332 then next=1 else next=4
# 1 NODE: if [Blood Pressure Cuff Mean (std)] < 15.655097007751465 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Temperature (mean)] < 36.51625061035156 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=1
# TREE: 59
# 0 NODE: if [Sum of D10W (input)] < 62.06500053405762 then next=1 else next=4
# 1 NODE: if [Birth Weight (kg)] < 1.3149999976158142 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Glucometer (mean)] < 58.69999885559082 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 60
# 0 NODE: if [Sum of D10W (input)] < 62.06500053405762 then next=1 else next=4
# 1 NODE: if [Birth Weight (kg)] < 1.3125 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Respiratory Rate (mean)] < 46.16666603088379 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 61
# 0 NODE: if [Respiratory Rate (std)] < 6.013504981994629 then next=1 else next=4
# 1 NODE: if [Skin Temperature (mean)] < 36.08124923706055 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Platelet] < 258.5 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 62
# 0 NODE: if [Heart Rate (mena)] < 155.77083587646484 then next=1 else next=4
# 1 NODE: if [SaO2 (std)] < 4.946933031082153 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Blood Pressure Cuff Mean (variance)] < 38.43333435058594 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=1
# TREE: 63
# 0 NODE: if [SaO2 (variance)] < 24.473731994628906 then next=1 else next=4
# 1 NODE: if [Respiratory Rate (mean)] < 34.24264717102051 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Birth Weight (kg)] < 2.5700000524520874 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 64
# 0 NODE: if [Sum of D10W (input)] < 62.06500053405762 then next=1 else next=4
# 1 NODE: if [Skin Temperature (mean)] < 36.04701614379883 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Respiratory Rate (variance)] < 90.0715560913086 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 65
# 0 NODE: if [Birth Weight (kg)] < 1.3125 then next=1 else next=4
# 1 NODE: if [Sum of D10W (input)] < 62.06500053405762 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [SaO2 (variance)] < 12.882246494293213 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 66
# 0 NODE: if [Glucometer (std)] < 30.305109977722168 then next=1 else next=4
# 1 NODE: if [SaO2 (mean)] < 92.35416412353516 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Temperature (mean)] < 36.01702880859375 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 67
# 0 NODE: if [Heart Rate (mena)] < 155.77083587646484 then next=1 else next=4
# 1 NODE: if [Sum of D10W (input)] < 35.14999961853027 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Sum of D10W (input)] < 122.0112533569336 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 68
# 0 NODE: if [Blood Pressure Cuff Mean (mean)] < 39.16025733947754 then next=1 else next=4
# 1 NODE: if [Temperature (mean)] < 36.01041793823242 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Blood Pressure Cuff Systolic (variance)] < 248.47618865966797 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 69
# 0 NODE: if [Birth Weight (kg)] < 1.3125 then next=1 else next=4
# 1 NODE: if [Heart Rate (variance)] < 242.578857421875 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=1
# 4 NODE: if [Temperature (mean)] < 36.517499923706055 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 70
# 0 NODE: if [Sum of D10W (input)] < 62.06500053405762 then next=1 else next=4
# 1 NODE: if [Skin Temperature (std)] < 0.09350953251123428 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Respiratory Rate (mean)] < 34.331932067871094 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 71
# 0 NODE: if [Birth Weight (kg)] < 1.3125 then next=1 else next=4
# 1 NODE: if [Sum of D10W (input)] < 62.06500053405762 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Temperature (mean)] < 36.01079559326172 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=0
# TREE: 72
# 0 NODE: if [Blood Pressure Cuff Systolic (mean)] < 56.07291603088379 then next=1 else next=4
# 1 NODE: if [Temperature (std)] < 0.5200751423835754 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [SaO2 (mean)] < 90.41964340209961 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 73
# 0 NODE: if [Temperature (mean)] < 36.01213264465332 then next=1 else next=4
# 1 NODE: if [Blood Pressure Cuff Systolic (std)] < 17.694802284240723 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Temperature (mean)] < 36.51625061035156 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=1
# TREE: 74
# 0 NODE: if [Sum of D10W (input)] < 62.06500053405762 then next=1 else next=4
# 1 NODE: if [SaO2 (mean)] < 96.05416488647461 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Blood Pressure Cuff Mean (variance)] < 141.3095245361328 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=1
# TREE: 75
# 0 NODE: if [Heart Rate (mena)] < 155.77083587646484 then next=1 else next=4
# 1 NODE: if [SaO2 (mean)] < 93.22916793823242 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Sum of D10W (input)] < 122.0112533569336 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 76
# 0 NODE: if [SaO2 (std)] < 4.946933031082153 then next=1 else next=4
# 1 NODE: if [Respiratory Rate (std)] < 7.720089435577393 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Respiratory Rate (mean)] < 54.85416603088379 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 77
# 0 NODE: if [Respiratory Rate (variance)] < 36.16231918334961 then next=1 else next=4
# 1 NODE: if [Skin Temperature (std)] < 0.11792866513133049 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Respiratory Rate (mean)] < 42.22916603088379 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 78
# 0 NODE: if [Skin Temperature (mean)] < 36.324039459228516 then next=1 else next=4
# 1 NODE: if [SaO2 (variance)] < 23.691123008728027 then next=2 else next=3
# 2 LEAF: return class=0
# 3 LEAF: return class=1
# 4 NODE: if [Sum of D10W (input)] < 110.20000076293945 then next=5 else next=6
# 5 LEAF: return class=1
# 6 LEAF: return class=0
# TREE: 79
# 0 NODE: if [Birth Weight (kg)] < 1.3125 then next=1 else next=4
# 1 NODE: if [Sum of D10W (input)] < 62.06500053405762 then next=2 else next=3
# 2 LEAF: return class=1
# 3 LEAF: return class=0
# 4 NODE: if [Blood Pressure Cuff Systolic (variance)] < 41.894737243652344 then next=5 else next=6
# 5 LEAF: return class=0
# 6 LEAF: return class=0
